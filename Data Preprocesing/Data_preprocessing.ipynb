# %% [markdown]
# ![alt text](./meta/data-preprocessing.png)

# %% [markdown]
# When you have data you classify it to Numerical | Categorical/Ordinal | Text | Image | Audio | Video.
#
# Then you have to preprocess it to make it ready for the model.
#
# ## Numerical Data
# you can count it, scale it, normalize it, standardize it, etc.
#
# ## Categorical/Ordinal Data
# you can classify it, encode it, etc.
#
# ## identify the target variable
# in this example income is the target variable

# %%
import pandas as pd

# %%
df = pd.read_csv('../Dataset/EDA_data.csv')
df.head(20)
# Out:
#       Age   Income    Education  Gender           City  Productivity  Rating  \
# 0     NaN  50000.0          NaN     NaN            NaN          75.0     4.2
# 1     NaN  60000.0     Bachelor    Male        Chicago           NaN     3.8
# 2    22.0  48000.0          NaN    Male            NaN          60.0     4.5
# 3     NaN  75000.0          PhD    Male  San Francisco           NaN     4.0
# 4    28.0      NaN     Bachelor  Female        Chicago           NaN     NaN
# 5     NaN      NaN          NaN    Male            NaN           NaN     NaN
# 6    33.0  68000.0       Master     NaN    Los Angeles          85.0     4.2
# 7    40.0  80000.0          NaN    Male  San Francisco          78.0     4.6
# 8     NaN  55000.0          PhD     NaN       New York          65.0     3.9
# 9    22.0  90000.0  High School    Male        Chicago          95.0     NaN
# 10   31.0  67000.0          NaN  Female            NaN          88.0     NaN
# ...

# %%
df.shape
# Out:
# (20, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Age           12 non-null     float64
#  1   Income        14 non-null     float64
#  2   Education     14 non-null     object
#  3   Gender        14 non-null     object
#  4   City          14 non-null     object
#  5   Productivity  14 non-null     float64
#  6   Rating        13 non-null     float64
#  7   Experience    13 non-null     float64
#  8   Department    14 non-null     object
# dtypes: float64(5), object(4)
# memory usage: 1.5+ KB

# %% [markdown]
# ## Numerical Data and categorical data are handled differently for the missing data

# %%
df.isnull().sum()
# Out:
# Age             8
# Income          6
# Education       6
# Gender          6
# City            6
# Productivity    6
# Rating          7
# Experience      7
# Department      6
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.dropna(axis=0,how='all')
# Out:
#       Age   Income    Education  Gender           City  Productivity  Rating  \
# 0     NaN  50000.0          NaN     NaN            NaN          75.0     4.2
# 1     NaN  60000.0     Bachelor    Male        Chicago           NaN     3.8
# 2    22.0  48000.0          NaN    Male            NaN          60.0     4.5
# 3     NaN  75000.0          PhD    Male  San Francisco           NaN     4.0
# 4    28.0      NaN     Bachelor  Female        Chicago           NaN     NaN
# 5     NaN      NaN          NaN    Male            NaN           NaN     NaN
# 6    33.0  68000.0       Master     NaN    Los Angeles          85.0     4.2
# 7    40.0  80000.0          NaN    Male  San Francisco          78.0     4.6
# 8     NaN  55000.0          PhD     NaN       New York          65.0     3.9
# 9    22.0  90000.0  High School    Male        Chicago          95.0     NaN
# 10   31.0  67000.0          NaN  Female            NaN          88.0     NaN
# ...

# %%
# filter the data
df[df['Rating'] > 4.2]
# Out:
#      Age   Income    Education Gender           City  Productivity  Rating  \
# 2   22.0  48000.0          NaN   Male            NaN          60.0     4.5
# 7   40.0  80000.0          NaN   Male  San Francisco          78.0     4.6
# 15   NaN      NaN     Bachelor   Male       New York           NaN     4.7
# 19  34.0      NaN  High School   Male            NaN          82.0     4.5
#
#     Experience Department
# 2          7.0  Marketing
# 7          3.0        NaN
# 15         NaN         HR
# 19         7.0         HR

# %%
# Choosing relevant to impue the missing values depending on the context
print(df['Age'].mean())
print(df['Age'].median())
print(df['Age'].mode())
# Out:
# 35.75
# 30.0
# 0    22.0
# 1    28.0
# Name: Age, dtype: float64

# %%
df['Age'].fillna(df['Age'].median(), inplace=True)

# %%
# Impute Income with mean
# Impute Productivity with mean
# Impute Rating with mean
# Impute experience with median
df['Income'].fillna(df['Income'].mean(), inplace=True)
df['Productivity'].fillna(df['Productivity'].mean(), inplace=True)
df['Rating'].fillna(df['Rating'].mean(), inplace=True)
df['Experience'].fillna(df['Experience'].median(), inplace=True)

# %% [markdown]
# ### mean and median, remember in numerical cols, when ther are high outliers to avoid a little or more fluctuation in the data, we use median instead of mean.

# %%
df.isnull().sum()
# Out:
# Age             0
# Income          0
# Education       6
# Gender          6
# City            6
# Productivity    0
# Rating          0
# Experience      0
# Department      6
# dtype: int64

# %%
df
# Out:
#       Age   Income    Education  Gender           City  Productivity  \
# 0    30.0  50000.0          NaN     NaN            NaN     75.000000
# 1    30.0  60000.0     Bachelor    Male        Chicago     78.571429
# 2    22.0  48000.0          NaN    Male            NaN     60.000000
# 3    30.0  75000.0          PhD    Male  San Francisco     78.571429
# 4    28.0  64000.0     Bachelor  Female        Chicago     78.571429
# 5    30.0  64000.0          NaN    Male            NaN     78.571429
# 6    33.0  68000.0       Master     NaN    Los Angeles     85.000000
# 7    40.0  80000.0          NaN    Male  San Francisco     78.000000
# 8    30.0  55000.0          PhD     NaN       New York     65.000000
# 9    22.0  90000.0  High School    Male        Chicago     95.000000
# 10   31.0  67000.0          NaN  Female            NaN     88.000000
# 11   29.0  59000.0     Bachelor     NaN  San Francisco     75.000000
# 12   30.0  64000.0          PhD  Female            NaN     80.000000
# ...

# %%
df['Gender'].mode()[0]
# Out:
# 'Male'

# %%
# Impute the gender with the mode
df['Gender'].fillna(df['Gender'].mode()[0], inplace=True)
df.isnull().sum()
# Out:
# Age             0
# Income          0
# Education       6
# Gender          0
# City            6
# Productivity    0
# Rating          0
# Experience      0
# Department      6
# dtype: int64

# %%
df
# Out:
#       Age   Income    Education  Gender           City  Productivity  \
# 0    30.0  50000.0          NaN    Male            NaN     75.000000
# 1    30.0  60000.0     Bachelor    Male        Chicago     78.571429
# 2    22.0  48000.0          NaN    Male            NaN     60.000000
# 3    30.0  75000.0          PhD    Male  San Francisco     78.571429
# 4    28.0  64000.0     Bachelor  Female        Chicago     78.571429
# 5    30.0  64000.0          NaN    Male            NaN     78.571429
# 6    33.0  68000.0       Master    Male    Los Angeles     85.000000
# 7    40.0  80000.0          NaN    Male  San Francisco     78.000000
# 8    30.0  55000.0          PhD    Male       New York     65.000000
# 9    22.0  90000.0  High School    Male        Chicago     95.000000
# 10   31.0  67000.0          NaN  Female            NaN     88.000000
# 11   29.0  59000.0     Bachelor    Male  San Francisco     75.000000
# 12   30.0  64000.0          PhD  Female            NaN     80.000000
# ...

# %%
#Impute the Education column with 'Others'
df['Education'].fillna('Others', inplace=True)
df.isnull().sum()
# Out:
# Age             0
# Income          0
# Education       0
# Gender          0
# City            6
# Productivity    0
# Rating          0
# Experience      0
# Department      6
# dtype: int64

# %%
df
# Out:
#       Age   Income    Education  Gender           City  Productivity  \
# 0    30.0  50000.0       Others    Male            NaN     75.000000
# 1    30.0  60000.0     Bachelor    Male        Chicago     78.571429
# 2    22.0  48000.0       Others    Male            NaN     60.000000
# 3    30.0  75000.0          PhD    Male  San Francisco     78.571429
# 4    28.0  64000.0     Bachelor  Female        Chicago     78.571429
# 5    30.0  64000.0       Others    Male            NaN     78.571429
# 6    33.0  68000.0       Master    Male    Los Angeles     85.000000
# 7    40.0  80000.0       Others    Male  San Francisco     78.000000
# 8    30.0  55000.0          PhD    Male       New York     65.000000
# 9    22.0  90000.0  High School    Male        Chicago     95.000000
# 10   31.0  67000.0       Others  Female            NaN     88.000000
# 11   29.0  59000.0     Bachelor    Male  San Francisco     75.000000
# 12   30.0  64000.0          PhD  Female            NaN     80.000000
# ...

# %%
# Impute the Department with 'Unknown'
df['Department'].fillna('Unknown', inplace=True)
df.isnull().sum()
# Out:
# Age             0
# Income          0
# Education       0
# Gender          0
# City            6
# Productivity    0
# Rating          0
# Experience      0
# Department      0
# dtype: int64

# %%
df
# Out:
#       Age   Income    Education  Gender           City  Productivity  \
# 0    30.0  50000.0       Others    Male            NaN     75.000000
# 1    30.0  60000.0     Bachelor    Male        Chicago     78.571429
# 2    22.0  48000.0       Others    Male            NaN     60.000000
# 3    30.0  75000.0          PhD    Male  San Francisco     78.571429
# 4    28.0  64000.0     Bachelor  Female        Chicago     78.571429
# 5    30.0  64000.0       Others    Male            NaN     78.571429
# 6    33.0  68000.0       Master    Male    Los Angeles     85.000000
# 7    40.0  80000.0       Others    Male  San Francisco     78.000000
# 8    30.0  55000.0          PhD    Male       New York     65.000000
# 9    22.0  90000.0  High School    Male        Chicago     95.000000
# 10   31.0  67000.0       Others  Female            NaN     88.000000
# 11   29.0  59000.0     Bachelor    Male  San Francisco     75.000000
# 12   30.0  64000.0          PhD  Female            NaN     80.000000
# ...

# %%
# Impute City with mode
df['City'].fillna(df['City'].mode()[0], inplace=True)
df.isnull().sum()
# Out:
# Age             0
# Income          0
# Education       0
# Gender          0
# City            0
# Productivity    0
# Rating          0
# Experience      0
# Department      0
# dtype: int64

# %%
df
# Out:
#       Age   Income    Education  Gender           City  Productivity  \
# 0    30.0  50000.0       Others    Male  San Francisco     75.000000
# 1    30.0  60000.0     Bachelor    Male        Chicago     78.571429
# 2    22.0  48000.0       Others    Male  San Francisco     60.000000
# 3    30.0  75000.0          PhD    Male  San Francisco     78.571429
# 4    28.0  64000.0     Bachelor  Female        Chicago     78.571429
# 5    30.0  64000.0       Others    Male  San Francisco     78.571429
# 6    33.0  68000.0       Master    Male    Los Angeles     85.000000
# 7    40.0  80000.0       Others    Male  San Francisco     78.000000
# 8    30.0  55000.0          PhD    Male       New York     65.000000
# 9    22.0  90000.0  High School    Male        Chicago     95.000000
# 10   31.0  67000.0       Others  Female  San Francisco     88.000000
# 11   29.0  59000.0     Bachelor    Male  San Francisco     75.000000
# 12   30.0  64000.0          PhD  Female  San Francisco     80.000000
# ...

# %% [markdown]
# ## Outlier

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='Age', data=df, color='orange')
plt.title('Boxplot of Age')
plt.show()

# %%
# Mean and Standard deviation technique 
import numpy as np

age_mean = df['Age'].mean()
age_std = df['Age'].std()
df['Age'] = np.where((df['Age'] > age_mean + 3 * age_std) | \
                     (df['Age'] < age_mean - 3 * age_std), np.nan, df['Age'])
df['Age']
# Out:
# 0     30.0
# 1     30.0
# 2     22.0
# 3     30.0
# 4     28.0
# 5     30.0
# 6     33.0
# 7     40.0
# 8     30.0
# 9     22.0
# 10    31.0
# 11    29.0
# 12    30.0
# 13    38.0
# 14    24.0
# 15    30.0
# 16     NaN
# 17    30.0
# 18    28.0
# 19    34.0
# Name: Age, dtype: float64

# %%
df['Age'].fillna(df['Age'].median(), inplace=True)
df
# Out:
#      Age   Income    Education  Gender           City  Productivity    Rating  \
# 0   30.0  50000.0       Others    Male  San Francisco     75.000000  4.200000
# 1   30.0  60000.0     Bachelor    Male        Chicago     78.571429  3.800000
# 2   22.0  48000.0       Others    Male  San Francisco     60.000000  4.500000
# 3   30.0  75000.0          PhD    Male  San Francisco     78.571429  4.000000
# 4   28.0  64000.0     Bachelor  Female        Chicago     78.571429  4.207692
# 5   30.0  64000.0       Others    Male  San Francisco     78.571429  4.207692
# 6   33.0  68000.0       Master    Male    Los Angeles     85.000000  4.200000
# 7   40.0  80000.0       Others    Male  San Francisco     78.000000  4.600000
# 8   30.0  55000.0          PhD    Male       New York     65.000000  3.900000
# 9   22.0  90000.0  High School    Male        Chicago     95.000000  4.207692
# 10  31.0  67000.0       Others  Female  San Francisco     88.000000  4.207692
# ...

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='Age', data=df, color='orange')
plt.title('Boxplot of Age')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='Income', data=df, color='orange')
plt.title('Boxplot of Age')
plt.show()

# %% [markdown]
# ![alt text](./meta/IQRTech.png)

# %%
quartiles = df['Income'].quantile([0.25, 0.75])
iqr = quartiles[0.75] - quartiles[0.25]
print(quartiles[0.75] , quartiles[0.25], iqr)
ul = quartiles[0.75] + 1.5*iqr
ll = quartiles[0.25] - 1.5*iqr
print(ul, ll)
outliers = df[(df['Income'] > ul) | (df['Income'] < ll)]['Income']
print(outliers)
df['Income'].replace(outliers[9], iqr, inplace=True)
df['Income']
# Out:
# 68250.0 58000.0 10250.0
# 83625.0 42625.0
# 9    90000.0
# Name: Income, dtype: float64
# 0     50000.0
# 1     60000.0
# 2     48000.0
# 3     75000.0
# 4     64000.0
# 5     64000.0
# 6     68000.0
# 7     80000.0
# 8     55000.0
# 9     10250.0
# 10    67000.0
# 11    59000.0
# 12    64000.0
# 13    72000.0
# 14    49000.0
# 15    64000.0
# 16    64000.0
# 17    69000.0
# 18    54000.0
# 19    64000.0
# Name: Income, dtype: float64

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='Productivity', data=df, color='orange')
plt.title('Boxplot of Productivity')
plt.show()

# %%
# computer mean
mean = df['Productivity'].mean()

# compute standard deviation
std = df['Productivity'].std()

# find the data points that are 3 standard deviation away from mean
df['Productivity'] = np.where((df['Productivity'] > age_mean + 3 * age_std) | \
                              (df['Productivity'] < age_mean - 3 * age_std), np.nan, df['Productivity'])

# impute the outliers with median
df['Productivity'].fillna(df['Productivity'].median(), inplace=True)
df
# Out:
#      Age   Income    Education  Gender           City  Productivity    Rating  \
# 0   30.0  50000.0       Others    Male  San Francisco     75.000000  4.200000
# 1   30.0  60000.0     Bachelor    Male        Chicago     78.571429  3.800000
# 2   22.0  48000.0       Others    Male  San Francisco     60.000000  4.500000
# 3   30.0  75000.0          PhD    Male  San Francisco     78.571429  4.000000
# 4   28.0  64000.0     Bachelor  Female        Chicago     78.571429  4.207692
# 5   30.0  64000.0       Others    Male  San Francisco     78.571429  4.207692
# 6   33.0  68000.0       Master    Male    Los Angeles     78.571429  4.200000
# 7   40.0  80000.0       Others    Male  San Francisco     78.000000  4.600000
# 8   30.0  55000.0          PhD    Male       New York     65.000000  3.900000
# 9   22.0  10250.0  High School    Male        Chicago     78.571429  4.207692
# 10  31.0  67000.0       Others  Female  San Francisco     78.571429  4.207692
# ...

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='Experience', data=df, color='orange')
plt.title('Boxplot of Expeerience')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='Rating', data=df, color='orange')
plt.title('Boxplot of Rating')
plt.show()

# %% [markdown]
# # Visualize the data

# %%
df
# Out:
#      Age   Income    Education  Gender           City  Productivity    Rating  \
# 0   30.0  50000.0       Others    Male  San Francisco     75.000000  4.200000
# 1   30.0  60000.0     Bachelor    Male        Chicago     78.571429  3.800000
# 2   22.0  48000.0       Others    Male  San Francisco     60.000000  4.500000
# 3   30.0  75000.0          PhD    Male  San Francisco     78.571429  4.000000
# 4   28.0  64000.0     Bachelor  Female        Chicago     78.571429  4.207692
# 5   30.0  64000.0       Others    Male  San Francisco     78.571429  4.207692
# 6   33.0  68000.0       Master    Male    Los Angeles     78.571429  4.200000
# 7   40.0  80000.0       Others    Male  San Francisco     78.000000  4.600000
# 8   30.0  55000.0          PhD    Male       New York     65.000000  3.900000
# 9   22.0  10250.0  High School    Male        Chicago     78.571429  4.207692
# 10  31.0  67000.0       Others  Female  San Francisco     78.571429  4.207692
# ...

# %%
plt.figure(figsize=(10, 6))
sns.histplot(x='Income', data=df, color='orange')
plt.title('Histogram of Income')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(x='Productivity', data=df, kde=True, color='blue')
plt.title('Histogram of Income')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(x='Rating', data=df, kde=True, color='red')
plt.title('Histogram of Income')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(x='Age', data=df, kde=True, color='green')
plt.title('Histogram of Income')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(x='Experience', data=df, kde=True, color='blue')
plt.title('Histogram of Income')
plt.show()

# %%
# Correlation heatmap 
# Heatmap helps to find the correlation between the variables 
plt.figure(figsize=(10, 8))
sns.heatmap(df[['Age','Experience','Rating', 'Income','Productivity']].corr(), annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()

# %%
# Find the relationship between categorical variables and numerical variables 
# by using binning technique you convert the numerical variables into categorical variables 

bins = [9000, 55000, 70000, 95000]
df['Income_binned'] = pd.cut(df['Income'], bins, labels=['Low', 'Medium', 'High'])
df
# Out:
#      Age   Income    Education  Gender           City  Productivity    Rating  \
# 0   30.0  50000.0       Others    Male  San Francisco     75.000000  4.200000
# 1   30.0  60000.0     Bachelor    Male        Chicago     78.571429  3.800000
# 2   22.0  48000.0       Others    Male  San Francisco     60.000000  4.500000
# 3   30.0  75000.0          PhD    Male  San Francisco     78.571429  4.000000
# 4   28.0  64000.0     Bachelor  Female        Chicago     78.571429  4.207692
# 5   30.0  64000.0       Others    Male  San Francisco     78.571429  4.207692
# 6   33.0  68000.0       Master    Male    Los Angeles     78.571429  4.200000
# 7   40.0  80000.0       Others    Male  San Francisco     78.000000  4.600000
# 8   30.0  55000.0          PhD    Male       New York     65.000000  3.900000
# 9   22.0  10250.0  High School    Male        Chicago     78.571429  4.207692
# 10  31.0  67000.0       Others  Female  San Francisco     78.571429  4.207692
# ...

# %%
sns.countplot(df, x='Income_binned', hue='Gender')
# Out:
# <Axes: xlabel='Income_binned', ylabel='count'>

# %%
sns.countplot(df, x='Income_binned', hue='Experience')
# Out:
# <Axes: xlabel='Income_binned', ylabel='count'>
