# %% [markdown]
# ## Topics and Algorithms by Module:
#
# **Module 1: Course Introduction**
#
# - **Topics:** Overview of machine learning, course structure, learning objectives.
# - **Algorithms:** Not applicable.
#
# **Module 2: Relationship between AI, ML, and Data Science**
#
# - **Topics:** Definitions, distinctions, applications, overlap between the fields.
# - **Algorithms:** Not applicable.
#
# —>Master EDA + reporting and visualization.
#
# **Module 3: Supervised Learning**
#
# - **Topics:** Regression, classification, accuracy metrics, cost functions, model evaluation, real-life scenarios.
# - **Algorithms:** Linear regression, Bigmart, logistic regression, Naive Bayes, support vector machines (SVM), decision trees, random forest.
#
# **Module 4: Decision Trees and Random Forests**
#
# - **Topics:** Decision tree formation, choosing classifiers, overfitting, random forests, bagging, bootstrapping.
# - **Algorithms:** Decision tree, random forest.
#
# **Module 5: Unsupervised Learning**
#
# - **Topics:** Clustering, hierarchical clustering, K-means clustering, cluster applications, optimal cluster number.
# - **Algorithms:** Hierarchical clustering, K-means clustering.
#
# **Module 6: Time Series Modeling**
#
# - **Topics:** Time series patterns, stationarity, non-stationarity removal, forecasting models, time series analysis steps.
# - **Algorithms:** Specific models not mentioned, but likely ARIMA, SARIMA, moving averages, exponential smoothing.
#
# **Module 7: Ensemble Learning**
#
# - **Topics:** AdaBoost, gradient boosting, XGBoost, model selection, cross-validation.
# - **Algorithms:** AdaBoost, XGBoost.
#
# **Module 8: Recommender Systems**
#
# - **Topics:** Purposes, paradigms, collaborative filtering, association rule mining, Apriori algorithm, user recommendations.
# - **Algorithms:** Collaborative filtering, Apriori.
#
# **Module 9: Guest Lecture (Andrew McAfee)**
#
# - **Topics:** Mind-machine combinations, human-computer collaboration, error reduction.
# - **Algorithms:** Not applicable.
#
# **Module 10: Case Studies**
#
# - **Topics:** California housing price prediction, phishing detector with logistic regression.
# - **Algorithms:** Linear regression, logistic regression.
