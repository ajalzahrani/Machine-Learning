# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../1_Dataset/FixedSalaryData.csv')
df.head()
# Out:
#    YearsExperience  Salary
# 0              1.0  1000.0
# 1              1.5  1500.0
# 2              2.0  2000.0
# 3              2.5  2500.0
# 4              3.0  3000.0

# %%
# 9. Swarmplot of 'Productivity' vs 'Education'
import seaborn as sns
plt.figure(figsize=(10, 6))
sns.set_theme(style="ticks")
sns.swarmplot(x='YearsExperience', y='Salary', data=df)
plt.title("Swarmplot of 'City' vs 'Income'")
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
x = df[['YearsExperience']]
y = df[['Salary']]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0 )

# %%
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
# Evaluating the model
mse = mean_squared_error(y_test, y_pred)
r2  = r2_score(y_test, y_pred)
print('MSE: ', mse)
print('R2: ', r2)
# Out:
# MSE:  9.305781891221562e-26
# R2:  1.0

# %%
new_ex_value = 13
new_ex = np.array([new_ex_value]).reshape(-1, 1)
pred_salary = model.predict(new_ex)
print('Predicted Salary for ', new_ex_value,' ex years is: ', pred_salary)
# Out:
# Predicted Salary for  13  ex years is:  [[13000.]]
# /usr/local/lib/python3.10/site-packages/sklearn/base.py:465: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
